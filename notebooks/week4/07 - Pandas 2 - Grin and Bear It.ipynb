# %%
from IPython.display import Image

# %%
Image(filename="panda_attack1.jpg")

# %% [markdown]
# Todo:
#
# * Get ATUS data
# * Talk about how to learn about a data set
# * Slicing a data set
# * Joining two data sets
