# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import preprocessing
from sklearn.cluster import KMeans
from PIL import Image

# %%
# %matplotlib inline

# %%
im = Image.open("bird_small.jpg")
imdata = np.asarray(im)
plt.imshow(imdata)
imdata.shape
# Out:
# (128, 128, 3)

# %%
all_pixels = imdata.reshape(-1, 3).astype(np.float)
all_pixels.shape
# Out:
# (16384, 3)

# %%
kmeans = KMeans(64)
kmeans.fit(all_pixels)
pixel_groups = kmeans.predict(all_pixels)

# %%
pixel_groups[0:100]
# Out:
# array([31, 54, 31, 31, 31, 54, 54, 54, 31,  3, 31, 31, 31, 31, 31, 31, 31,
#        31, 31, 31, 31, 31, 31, 31, 31, 31, 31,  3, 31, 54, 54, 54, 54, 54,
#        37, 54, 31, 31, 31, 31, 31, 31, 31, 31,  3,  3,  3,  3, 16,  3,  3,
#        16, 16, 16, 16, 16, 16, 16, 16, 16,  3, 16, 16, 16, 41, 41, 26, 26,
#        41, 41, 16, 41, 41, 41, 41, 10, 10, 10, 10, 10, 10, 10, 10,  3,  3,
#         3,  3, 54, 31, 16,  3, 54, 59,  1, 59, 12, 14, 23,  9, 17], dtype=int32)

# %%
# new_colors = np.array([color.tolist()[::-1] for color in kmeans.cluster_centers_]).astype(np.int)
new_colors = kmeans.cluster_centers_.astype(np.int)

# %%
new_pixels = np.array([new_colors[c] for c in pixel_groups])
new_pixels.shape
# Out:
# (16384, 3)

# %%
new_image_data = new_pixels.reshape((128, 128, 3))

# %%
plt.imshow(new_image_data)

# %%
all_pixels[0]
# Out:
# array([ 219.,  180.,  103.])

# %%
new_pixels[0]
# Out:
# array([113,  75,  34])
